# %%
# !python iot_slm_notification.py
# Out:
#   IoT-SLM  Notification System
#   RNN-GRU Â· K-Means Â· Decision Tree
#   BMP280 Â· AHT20 Â· BH1750
#
# [1] Simulating 60-day IoT sensor data ...
#     Total readings : 2880
#     Fault events   : 68 (2.4%)
#
# [2] Extracting sliding-window features (window=12 steps = 6h) ...
#     Feature matrix : (2856, 34)  (34 features per window)
#
# [3] Fitting K-Means (k=8) ...
#     Cluster assignments:
#       Cluster 0: NORMAL_NIGHT               (475 windows)
#       Cluster 1: NORMAL_DAY                 (260 windows)
#       Cluster 2: BORDERLINE                 (513 windows)
#       Cluster 3: NORMAL_NIGHT_1             (284 windows)
#       Cluster 4: NORMAL_DAY_1               (583 windows)
#       Cluster 5: NORMAL_NIGHT_2             (348 windows)
#       Cluster 6: BORDERLINE_1               (205 windows)
#       Cluster 7: NORMAL_DAY_2               (188 windows)
#
# [4] Training IoT-SLM (GRU-RNN, 60 epochs) ...
#     Epoch  10/60  train=0.04140  val=0.00554
# ...

# %%
# !python iot_slm_xai.py
# Out:
# â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�
#   IoT-SLM  Â·  XAI Extension Pipeline
#   BMP280 | AHT20 | BH1750
# â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�â•�
#
# [1] Simulating IoT sensor data ...
#     Readings: 2880  |  True anomalies: 46
#
# [2] Training IoT-SLM (RNN-GRU) ...
#     Epoch  10/60 | Train:0.04049 | Val:0.00911
#     Epoch  20/60 | Train:0.03439 | Val:0.00633
#     Epoch  30/60 | Train:0.03467 | Val:0.00619
#     Epoch  40/60 | Train:0.03470 | Val:0.00547
#     Epoch  50/60 | Train:0.03308 | Val:0.00508
#     Epoch  60/60 | Train:0.03237 | Val:0.00512
#
# [3] Identifying anomalous windows in validation set ...
#     Found 5 anomaly windows for XAI analysis
#
# ...
